# %%
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler
import seaborn as sns
import math

from matplotlib.ticker import FormatStrFormatter
from matplotlib.lines import Line2D

plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 18
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['ytick.right'] = True
plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams['xtick.major.width'] = 1.0
plt.rcParams['ytick.major.width'] = 1.0
plt.rcParams['xtick.major.size'] = 4.5
colors = sns.color_palette('bright')
plt.rcParams['axes.prop_cycle'] = cycler(color=colors)

golden_ratio = 0.5 * (1.0 + math.sqrt(5.0))
ls = '--'

# %%
fig = plt.figure(figsize=(10,10))
plt.subplots_adjust(wspace=0.18, hspace=0.13)

plt.subplot(2,2,1)
f1 = np.loadtxt('datafiles/SB_model1_wOMT.txt')
f2 = np.loadtxt('datafiles/SB_model1_heom.txt')
f3 = np.loadtxt('datafiles/SB_model1_MASH.txt')
f4 = np.loadtxt('datafiles/SB_model1_OMT.txt')
f5 = np.loadtxt('datafiles/SB_model1_SQC.txt')
plt.text(0.7, 0.65, r'$\beta \omega_c = 0.25$' + '\n' \
            + r'$\Delta/\omega_c=1$' + '\n' + r'$\epsilon/\omega_c=1$' \
                + '\n' + r'$\Lambda/\omega_c=0.5$', transform=plt.gca().transAxes, horizontalalignment='center')
plt.plot(f1[:,0], f1[:,1], label='wOMT', ls=ls)
plt.plot(f2[:,0], f2[:,1], label='HEOM', ls=ls)
plt.plot(f3[:,0], f3[:,1], label='MASH', ls=ls)
plt.plot(f4[:,0], f4[:,1], label='OMT', ls=ls)
plt.plot(f5[:,0], f5[:,1], label='SQC', ls=ls)
plt.legend(frameon=False, loc=(0.5,0.2), fontsize=16)
plt.xlim([0,20])

plt.subplot(2,2,2)
f1 = np.loadtxt('datafiles/SB_model2_wOMT.txt')
f2 = np.loadtxt('datafiles/SB_model2_heom.txt')
f3 = np.loadtxt('datafiles/SB_model2_MASH.txt')
f4 = np.loadtxt('datafiles/SB_model2_OMT.txt')
f5 = np.loadtxt('datafiles/SB_model2_SQC.txt')
plt.text(0.7, 0.65, r'$\beta \omega_c = 5$' + '\n' \
            + r'$\Delta/\omega_c=1$' + '\n' + r'$\epsilon/\omega_c=1$' \
                + '\n' + r'$\Lambda/\omega_c=0.5$', transform=plt.gca().transAxes, horizontalalignment='center')
plt.plot(f1[:,0], f1[:,1], ls=ls)
plt.plot(f2[:,0], f2[:,1], ls=ls)
plt.plot(f3[:,0], f3[:,1], ls=ls)
plt.plot(f4[:,0], f4[:,1], ls=ls)
plt.plot(f5[:,0], f5[:,1], ls=ls)
plt.xlim([0,20])


plt.subplot(2,2,3)
f1 = np.loadtxt('datafiles/SB_model3_wOMT.txt')
f2 = np.loadtxt('datafiles/SB_model3_heom.txt')
f3 = np.loadtxt('datafiles/SB_model3_MASH.txt')
f4 = np.loadtxt('datafiles/SB_model3_OMT.txt')
f5 = np.loadtxt('datafiles/SB_model3_SQC.txt')
plt.plot(f1[:,0], f1[:,1], ls=ls)
plt.plot(f2[:,0], f2[:,1], ls=ls)
plt.plot(f3[:,0], f3[:,1], ls=ls)
plt.plot(f4[:,0], f4[:,1], ls=ls)
plt.plot(f5[:,0], f5[:,1], ls=ls)
plt.xlim([0,15])
plt.text(0.7, 0.65, r'$\beta \omega_c = 0.25$' + '\n' \
            + r'$\Delta/\omega_c=1$' + '\n' + r'$\epsilon/\omega_c=1.5$' \
                + '\n' + r'$\Lambda/\omega_c=3$', transform=plt.gca().transAxes, horizontalalignment='center')

plt.subplot(2,2,4)
f1 = np.loadtxt('datafiles/SB_model4_wOMT.txt')
f2 = np.loadtxt('datafiles/SB_model4_heom.txt')
f3 = np.loadtxt('datafiles/SB_model4_MASH.txt')
f4 = np.loadtxt('datafiles/SB_model4_OMT.txt')
f5 = np.loadtxt('datafiles/SB_model4_SQC.txt')
plt.text(0.7, 0.65, r'$\beta \omega_c = 0.25$' + '\n' \
            + r'$\Delta/\omega_c=1$' + '\n' + r'$\epsilon/\omega_c=3$' \
                + '\n' + r'$\Lambda/\omega_c=1.5$', transform=plt.gca().transAxes, horizontalalignment='center')
plt.plot(f1[:,0], f1[:,1], ls=ls)
plt.plot(f2[:,0], f2[:,1], ls=ls)
plt.plot(f3[:,0], f3[:,1], ls=ls)
plt.plot(f4[:,0], f4[:,1], ls=ls)
plt.plot(f5[:,0], f5[:,1], ls=ls)
plt.xlim([0,40])

fig.supxlabel(r'$\omega_c t$', y=0.05)
fig.supylabel(r'Population of diabat 1', x=0.05)

# plt.savefig('spin_boson_compare_pop1.pdf', bbox_inches='tight', dpi=800)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
plt.subplots_adjust(wspace=0.18, hspace=0.12)

plt.subplot(2,2,1)
f1 = np.loadtxt('datafiles/SB_model1_wOMT.txt')
f2 = np.loadtxt('datafiles/SB_model1_heom.txt')
f3 = np.loadtxt('datafiles/SB_model1_MASH.txt')
f4 = np.loadtxt('datafiles/SB_model1_OMT.txt')
f5 = np.loadtxt('datafiles/SB_model1_SQC.txt')
plt.text(0.7, 0.7, r'$\beta \omega_c = 0.25$' + '\n' \
            + r'$\Delta/\omega_c=1$' + '\n' + r'$\epsilon/\omega_c=1$' \
                + '\n' + r'$\Lambda/\omega_c=0.5$', transform=plt.gca().transAxes, horizontalalignment='center')
plt.plot(f1[:,0], f1[:,3], label='wOMT', ls=ls)
plt.plot(f2[:,0], f2[:,3], label='HEOM', ls=ls)
plt.plot(f3[:,0], f3[:,3], label='MASH', ls=ls)
plt.plot(f4[:,0], f4[:,3], label='OMT', ls=ls)
plt.plot(f5[:,0], f5[:,3], label='SQC', ls=ls)
plt.legend(frameon=False, loc=(0.4,0.2), fontsize=16)
plt.xlim([0,20])
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))

plt.subplot(2,2,2)
f1 = np.loadtxt('datafiles/SB_model2_wOMT.txt')
f2 = np.loadtxt('datafiles/SB_model2_heom.txt')
f3 = np.loadtxt('datafiles/SB_model2_MASH.txt')
f4 = np.loadtxt('datafiles/SB_model2_OMT.txt')
f5 = np.loadtxt('datafiles/SB_model2_SQC.txt')
plt.text(0.7, 0.7, r'$\beta \omega_c = 5$' + '\n' \
            + r'$\Delta/\omega_c=1$' + '\n' + r'$\epsilon/\omega_c=1$' \
                + '\n' + r'$\Lambda/\omega_c=0.5$', transform=plt.gca().transAxes, horizontalalignment='center')
plt.plot(f1[:,0], f1[:,3], ls=ls)
plt.plot(f2[:,0], f2[:,3], ls=ls)
plt.plot(f3[:,0], f3[:,3], ls=ls)
plt.plot(f4[:,0], f4[:,3], ls=ls)
plt.plot(f5[:,0], f5[:,3], ls=ls)
plt.yticks(np.linspace(-0.2, 0.4, 4))
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.xlim([0,20])



plt.subplot(2,2,3)
f1 = np.loadtxt('datafiles/SB_model3_wOMT.txt')
f2 = np.loadtxt('datafiles/SB_model3_heom.txt')
f3 = np.loadtxt('datafiles/SB_model3_MASH.txt')
f4 = np.loadtxt('datafiles/SB_model3_OMT.txt')
f5 = np.loadtxt('datafiles/SB_model3_SQC.txt')
plt.plot(f1[:,0], f1[:,3], ls=ls)
plt.plot(f2[:,0], f2[:,3], ls=ls)
plt.plot(f3[:,0], f3[:,3], ls=ls)
plt.plot(f4[:,0], f4[:,3], ls=ls)
plt.plot(f5[:,0], f5[:,3], ls=ls)
plt.yticks(np.linspace(-0.1, 0.1, 3))
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.xlim([0,15])
plt.text(0.7, 0.7, r'$\beta \omega_c = 0.25$' + '\n' \
            + r'$\Delta/\omega_c=1$' + '\n' + r'$\epsilon/\omega_c=1.5$' \
                + '\n' + r'$\Lambda/\omega_c=3$', transform=plt.gca().transAxes, horizontalalignment='center')

plt.subplot(2,2,4)
f1 = np.loadtxt('datafiles/SB_model4_wOMT.txt')
f2 = np.loadtxt('datafiles/SB_model4_heom.txt')
f3 = np.loadtxt('datafiles/SB_model4_MASH.txt')
f4 = np.loadtxt('datafiles/SB_model4_OMT.txt')
f5 = np.loadtxt('datafiles/SB_model4_SQC.txt')
plt.text(0.7, 0.7, r'$\beta \omega_c = 0.25$' + '\n' \
            + r'$\Delta/\omega_c=1$' + '\n' + r'$\epsilon/\omega_c=3$' \
                + '\n' + r'$\Lambda/\omega_c=1.5$', transform=plt.gca().transAxes, horizontalalignment='center')
plt.plot(f1[:,0], f1[:,3], ls=ls)
plt.plot(f2[:,0], f2[:,3], ls=ls)
plt.plot(f3[:,0], f3[:,3], ls=ls)
plt.plot(f4[:,0], f4[:,3], ls=ls)
plt.plot(f5[:,0], f5[:,3], ls=ls)
plt.yticks(np.linspace(-0.1, 0.2, 4))
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.xlim([0,40])

fig.supxlabel(r'$\omega_c t$', y=0.05)
fig.supylabel(r'Re ($\rho_{12}$)', x=0.04)

# plt.savefig('spin_boson_compare_r12.pdf', bbox_inches='tight', dpi=800)
plt.show()

# %%
heom_f1 = np.loadtxt('datafiles/HEOM_2LS_lambda_50_T_300_tau_100.txt')
womt_f1 = np.loadtxt('datafiles/wOMT_2LS_lambda_50_T_300_tau_100.txt')
mash_f1 = np.loadtxt('datafiles/mash_2LS_lambda_50_T_300_tau_100.txt')
omt_f1 = np.loadtxt('datafiles/OMT_2LS_lambda_50_T_300_tau_100.txt')
sqc_f1 = np.loadtxt('datafiles/SQC_2LS_lambda_50_T_300_tau_100.txt')

fig = plt.figure(figsize=(7*golden_ratio,15))
plt.subplots_adjust(wspace=0.18, hspace=0.12)

plt.subplot(3,2,1)
plt.plot(womt_f1[:,0], womt_f1[:,1], color=colors[0])
plt.plot(heom_f1[:,0], heom_f1[:,1], color=colors[1])
plt.plot(mash_f1[:,0], mash_f1[:,1], color=colors[2])
plt.plot(omt_f1[:,0], omt_f1[:,1], color=colors[3])
plt.plot(sqc_f1[:,0], sqc_f1[:,1], color=colors[4])
plt.plot(womt_f1[:,0], womt_f1[:,2], color=colors[0], ls='--')
plt.plot(heom_f1[:,0], heom_f1[:,2], color=colors[1], ls='--')
plt.plot(mash_f1[:,0], mash_f1[:,2], color=colors[2], ls='--')
plt.plot(omt_f1[:,0], omt_f1[:,2], color=colors[3], ls='--')
plt.plot(sqc_f1[:,0], sqc_f1[:,2], color=colors[4], ls='--')
plt.xlabel(r'$\omega_c t$', fontsize=20)
legends = [
    Line2D([0], [0], color=colors[0], label=r'wOMT'),
    Line2D([0], [0], color=colors[1], label=r'HEOM'),
    Line2D([0], [0], color=colors[2], label=r'MASH'),
    Line2D([0], [0], color=colors[3], label=r'OMT'),
    Line2D([0], [0], color=colors[4], label=r'SQC')
]
plt.legend(handles = legends, frameon=False, loc=(0.1,0.0), ncol=2)
plt.xlim(left=0.0,right=10)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.text(0.7, 0.7, r'$\rho_{22}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.7, 0.3, r'$\rho_{11}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.5, 0.9, r'$\omega_c=106.14 \, \mathrm{cm}^{-1}, T = 300\, \mathrm{K}$', transform=plt.gca().transAxes, horizontalalignment='center')

plt.subplot(3,2,2)
plt.plot(womt_f1[:,0], womt_f1[:,3], color=colors[0])
plt.plot(heom_f1[:,0], heom_f1[:,3], color=colors[1])
plt.plot(mash_f1[:,0], mash_f1[:,3], color=colors[2])
plt.plot(omt_f1[:,0], omt_f1[:,3], color=colors[3])
plt.plot(sqc_f1[:,0], sqc_f1[:,3], color=colors[4])
plt.plot(womt_f1[:,0], womt_f1[:,4], color=colors[0], ls='--')
plt.plot(heom_f1[:,0], heom_f1[:,4], color=colors[1], ls='--')
plt.plot(mash_f1[:,0], -mash_f1[:,4], color=colors[2], ls='--')
plt.plot(omt_f1[:,0], omt_f1[:,4], color=colors[3], ls='--')
plt.plot(sqc_f1[:,0], sqc_f1[:,4], color=colors[4], ls='--')
plt.xlim(left=0.0,right=10)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.xlabel(r'$\omega_c t$', fontsize=20)
plt.text(0.7, 0.50, r'$\Im [\rho_{12}]$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.7, 0.20, r'$\Re [\rho_{12}]$', transform=plt.gca().transAxes, fontsize=18)


heom_f1 = np.loadtxt('datafiles/HEOM_2LS_lambda_50_T_77_tau_100.txt')
womt_f1 = np.loadtxt('datafiles/wOMT_2LS_lambda_50_T_77_tau_100.txt')
mash_f1 = np.loadtxt('datafiles/mash_2LS_lambda_50_T_77_tau_100.txt')
omt_f1 = np.loadtxt('datafiles/OMT_2LS_lambda_50_T_77_tau_100.txt')
sqc_f1 = np.loadtxt('datafiles/SQC_2LS_lambda_50_T_77_tau_100.txt')

# plt.figure(figsize=(7*golden_ratio,5))
plt.subplot(3,2,3)
plt.plot(womt_f1[:,0], womt_f1[:,1], color=colors[0])
plt.plot(heom_f1[:,0], heom_f1[:,1], color=colors[1])
plt.plot(mash_f1[:,0], mash_f1[:,1], color=colors[2])
plt.plot(omt_f1[:,0], omt_f1[:,1], color=colors[3])
plt.plot(sqc_f1[:,0], sqc_f1[:,1], color=colors[4])
plt.plot(womt_f1[:,0], womt_f1[:,2], color=colors[0], ls='--')
plt.plot(heom_f1[:,0], heom_f1[:,2], color=colors[1], ls='--')
plt.plot(mash_f1[:,0], mash_f1[:,2], color=colors[2], ls='--')
plt.plot(omt_f1[:,0], omt_f1[:,2], color=colors[3], ls='--')
plt.plot(sqc_f1[:,0], sqc_f1[:,2], color=colors[4], ls='--')
plt.xlim(left=0.0,right=10)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.text(0.7, 0.80, r'$\rho_{22}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.7, 0.18, r'$\rho_{11}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.5, 0.9, r'$\omega_c=53.07 \, \mathrm{cm}^{-1}, T = 77\, \mathrm{K}$', transform=plt.gca().transAxes, horizontalalignment='center')


plt.subplot(3,2,4)
plt.plot(womt_f1[:,0], womt_f1[:,3], color=colors[0])
plt.plot(heom_f1[:,0], heom_f1[:,3], color=colors[1])
plt.plot(mash_f1[:,0], mash_f1[:,3], color=colors[2])
plt.plot(omt_f1[:,0], omt_f1[:,3], color=colors[3])
plt.plot(sqc_f1[:,0], sqc_f1[:,3], color=colors[4])
plt.plot(womt_f1[:,0], womt_f1[:,4], color=colors[0], ls='--')
plt.plot(heom_f1[:,0], heom_f1[:,4], color=colors[1], ls='--')
plt.plot(mash_f1[:,0], -mash_f1[:,4], color=colors[2], ls='--')
plt.plot(omt_f1[:,0], omt_f1[:,4], color=colors[3], ls='--')
plt.plot(sqc_f1[:,0], sqc_f1[:,4], color=colors[4], ls='--')
plt.xlim(left=0.0,right=10)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.text(0.7, 0.55, r'$\Im [\rho_{12}]$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.7, 0.28, r'$\Re [\rho_{12}]$', transform=plt.gca().transAxes, fontsize=18)
# plt.show()

heom_f1 = np.loadtxt('datafiles/HEOM_2LS_lambda_50_T_77_tau_50.txt')
womt_f1 = np.loadtxt('datafiles/wOMT_2LS_lambda_50_T_77_tau_50.txt')
mash_f1 = np.loadtxt('datafiles/mash_2LS_lambda_50_T_77_tau_50.txt')
omt_f1 = np.loadtxt('datafiles/OMT_2LS_lambda_50_T_77_tau_50.txt')
sqc_f1 = np.loadtxt('datafiles/SQC_2LS_lambda_50_T_77_tau_50.txt')

# plt.figure(figsize=(7*golden_ratio,5))
plt.subplot(3,2,5)
plt.plot(womt_f1[:,0], womt_f1[:,1], color=colors[0])
plt.plot(heom_f1[:,0], heom_f1[:,1], color=colors[1])
plt.plot(mash_f1[:,0], mash_f1[:,1], color=colors[2])
plt.plot(omt_f1[:,0], omt_f1[:,1], color=colors[3])
plt.plot(sqc_f1[:,0], sqc_f1[:,1], color=colors[4])
plt.plot(womt_f1[:,0], womt_f1[:,2], color=colors[0], ls='--')
plt.plot(heom_f1[:,0], heom_f1[:,2], color=colors[1], ls='--')
plt.plot(mash_f1[:,0], mash_f1[:,2], color=colors[2], ls='--')
plt.plot(omt_f1[:,0], omt_f1[:,2], color=colors[3], ls='--')
plt.plot(sqc_f1[:,0], sqc_f1[:,2], color=colors[4], ls='--')
plt.xlim(left=0.0,right=10)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.text(0.7, 0.8, r'$\rho_{22}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.7, 0.2, r'$\rho_{11}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.5, 0.9, r'$\omega_c=106.14 \, \mathrm{cm}^{-1}, T = 77\, \mathrm{K}$', transform=plt.gca().transAxes, horizontalalignment='center')


plt.subplot(3,2,6)
plt.plot(womt_f1[:,0], womt_f1[:,3], color=colors[0])
plt.plot(heom_f1[:,0], heom_f1[:,3], color=colors[1])
plt.plot(mash_f1[:,0], mash_f1[:,3], color=colors[2])
plt.plot(omt_f1[:,0], omt_f1[:,3], color=colors[3])
plt.plot(sqc_f1[:,0], sqc_f1[:,3], color=colors[4])
plt.plot(womt_f1[:,0], womt_f1[:,4], color=colors[0], ls='--')
plt.plot(heom_f1[:,0], heom_f1[:,4], color=colors[1], ls='--')
plt.plot(mash_f1[:,0], -mash_f1[:,4], color=colors[2], ls='--')
plt.plot(omt_f1[:,0], omt_f1[:,4], color=colors[3], ls='--')
plt.plot(sqc_f1[:,0], sqc_f1[:,4], color=colors[4], ls='--')
plt.xlim(left=0.0,right=10)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.text(0.7, 0.55, r'$\Im [\rho_{12}]$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.7, 0.28, r'$\Re [\rho_{12}]$', transform=plt.gca().transAxes, fontsize=18)

fig.supxlabel(r'$\omega_c t$', y=0.07, fontsize=20)

# plt.savefig('2LS_compare.pdf', bbox_inches='tight', dpi=800)

plt.show()

# %%
fig = plt.figure(figsize=(7*golden_ratio,5))
plt.subplots_adjust(wspace=0.15)
plt.subplot(1,2,1)
f1 = np.loadtxt('datafiles/HEOM_3LS_lambda_35_T_300_tau_100.txt')
f2 = np.loadtxt('datafiles/wOMT_3LS_lambda_35_T_300_tau_100.txt')
f3 = np.loadtxt('datafiles/mash_3LS_lambda_35_T_300_tau_100.txt')
f4 = np.loadtxt('datafiles/OMT_3LS_lambda_35_T_300_tau_100.txt')
f5 = np.loadtxt('datafiles/SQC_3LS_lambda_35_T_300_tau_100.txt')


plt.plot(f2[:,0], f2[:,1], label='wOMT', color=colors[0])
plt.plot(f1[:,0], f1[:,1], label='HEOM', color=colors[1])
plt.plot(f3[:,0], f3[:,1], label='MASH', color=colors[2])
plt.plot(f4[:,0], f4[:,1], label='OMT', color=colors[3])
plt.plot(f5[:,0], f5[:,1], label='SQC', color=colors[4])
plt.plot(f2[:,0], f2[:,3], color=colors[0], ls='--')
plt.plot(f1[:,0], f1[:,3], color=colors[1], ls='--')
plt.plot(f3[:,0], f3[:,3], color=colors[2], ls='--')
plt.plot(f4[:,0], f4[:,3], color=colors[3], ls='--')
plt.plot(f5[:,0], f5[:,3], color=colors[4], ls='--')
plt.text(0.7, 0.5, r'$\rho_{11}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.7, 0.2, r'$\rho_{33}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.6, 0.03, r'$\omega_c=53.07 \, \mathrm{cm}^{-1}, T = 300\, \mathrm{K}$', transform=plt.gca().transAxes, horizontalalignment='center')
plt.legend(frameon=False, ncol=2)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.xlim([0,10])

plt.subplot(1,2,2)

f1 = np.loadtxt('datafiles/HEOM_3LS_lambda_35_T_77_tau_50.txt')
f2 = np.loadtxt('datafiles/wOMT_3LS_lambda_35_T_77_tau_50.txt')
f3 = np.loadtxt('datafiles/mash_3LS_lambda_35_T_77_tau_50.txt')
f4 = np.loadtxt('datafiles/OMT_3LS_lambda_35_T_77_tau_50.txt')
f5 = np.loadtxt('datafiles/SQC_3LS_lambda_35_T_77_tau_50.txt')

plt.plot(f2[:,0], f2[:,1], color=colors[0])
plt.plot(f1[:,0], f1[:,1], color=colors[1])
plt.plot(f3[:,0], f3[:,1], color=colors[2])
plt.plot(f4[:,0], f4[:,1], color=colors[3])
plt.plot(f5[:,0], f5[:,1], color=colors[4])
plt.plot(f2[:,0], f2[:,2], color=colors[0], ls='--')
plt.plot(f1[:,0], f1[:,2], color=colors[1], ls='--')
plt.plot(f3[:,0], f3[:,2], color=colors[2], ls='--')
plt.plot(f4[:,0], f4[:,2], color=colors[3], ls='--')
plt.plot(f5[:,0], f5[:,2], color=colors[4], ls='--')
plt.text(0.7, 0.7, r'$\rho_{11}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.7, 0.3, r'$\rho_{33}$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.6, 0.03, r'$\omega_c=106.14 \, \mathrm{cm}^{-1}, T = 77\, \mathrm{K}$', transform=plt.gca().transAxes, horizontalalignment='center')
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.xlim([0,20])

fig.supxlabel(r'$\omega_c t$', y=-0.01, fontsize=20)
# plt.savefig('3LS_pop_compare.pdf', bbox_inches='tight', dpi=800)

plt.show()

plt.figure(figsize=(3.5*golden_ratio,5))

f1 = np.loadtxt('datafiles/HEOM_3LS_lambda_35_T_77_tau_50.txt')
f2 = np.loadtxt('datafiles/wOMT_3LS_lambda_35_T_77_tau_50.txt')
f3 = np.loadtxt('datafiles/mash_3LS_lambda_35_T_77_tau_50.txt')
f4 = np.loadtxt('datafiles/OMT_3LS_lambda_35_T_77_tau_50.txt')
f5 = np.loadtxt('datafiles/SQC_3LS_lambda_35_T_77_tau_50.txt')

plt.plot(f2[:,0], f2[:,4], label='wOMT', color=colors[0])
plt.plot(f1[:,0], f1[:,4], label='HEOM', color=colors[1])
plt.plot(f3[:,0], f3[:,4], label='MASH', color=colors[2])
plt.plot(f4[:,0], f4[:,4], label='OMT', color=colors[3])
plt.plot(f5[:,0], f5[:,4], label='SQC', color=colors[4])
plt.plot(f1[:,0], f1[:,5], color=colors[0], ls='--')
plt.plot(f2[:,0], f2[:,5], color=colors[1], ls='--')
plt.plot(f3[:,0], -f3[:,5], color=colors[2], ls='--')
plt.plot(f4[:,0], f4[:,5], color=colors[3], ls='--')
plt.plot(f5[:,0], f5[:,5], color=colors[4], ls='--')
plt.text(0.7, 0.9, r'$\Re [\rho_{12}]$', transform=plt.gca().transAxes, fontsize=18)
plt.text(0.7, 0.4, r'$\Im [\rho_{12}]$', transform=plt.gca().transAxes, fontsize=18)
plt.legend(frameon=False, ncol=2)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.xlim([0,20])
plt.xlabel(r'$\omega_c t$', fontsize=20)

# plt.savefig('3LS_coherence_compare.pdf', bbox_inches='tight', dpi=800)

plt.show()

# %%
f1 = np.loadtxt('datafiles/wOMT_7LS_lambda_35_T_300_tau_100.txt')
f2 = np.loadtxt('datafiles/mash_7LS_lambda_35_T_300_tau_100.txt')
f3 = np.loadtxt('datafiles/HEOM_7LS_lambda_35_T_300_tau_100.txt')
f4 = np.loadtxt('datafiles/OMT_7LS_lambda_35_T_300_tau_100.txt')
f5 = np.loadtxt('datafiles/SQC_7LS_lambda_35_T_300_tau_100.txt')
# f3a = np.loadtxt('HEOM_7LS_lambda_35_T_300_tau_100.txt')

plt.figure(figsize=(24,5))
plt.subplots_adjust(wspace=0.2)

plt.subplot(1,5,1)
for i in range(7):
    # plt.plot(f1[:,0], f1[:,i+1], label='%d'%(i+1), lw=3)
    plt.plot(f1[:,0], f1[:,i+1], color=colors[i], label='%d'%(i+1))
plt.text(0.7, 0.6, r'wOMT', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,10])
plt.legend(frameon=False, ncols=2, loc=(0.05,0.6))
plt.xlabel(r'$\omega_ct$', fontsize=18)

plt.subplot(1,5,2)
for i in range(7):
    plt.plot(f3[:,0], f3[:,i+1], color=colors[i])
plt.text(0.7, 0.6, 'HEOM', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,10])
plt.xlabel(r'$\omega_ct$', fontsize=18)

plt.subplot(1,5,3)
for i in range(7):
    plt.plot(f2[:,0], f2[:,i+1], color=colors[i])
plt.text(0.7, 0.6, r'MASH', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,10])
plt.xlabel(r'$\omega_ct$', fontsize=18)

plt.subplot(1,5,4)
for i in range(7):
    plt.plot(f4[:,0], f4[:,i+1], color=colors[i])
plt.text(0.7, 0.6, r'OMT', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,10])
plt.xlabel(r'$\omega_ct$', fontsize=18)

plt.subplot(1,5,5)
for i in range(7):
    plt.plot(f5[:,0], f5[:,i+1], color=colors[i])
plt.text(0.7, 0.6, r'SQC', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,10])
plt.xlabel(r'$\omega_ct$', fontsize=18)

# plt.savefig(pic_dir + '7LS_population_highT.pdf', bbox_inches='tight', dpi=800)

plt.show()

f1 = np.loadtxt('datafiles/full_g_wOMT_7LS_lambda_35_T_77_tau_50.txt')
f2 = np.loadtxt('datafiles/mash_7LS_lambda_35_T_77_tau_50.txt')
f3 = np.loadtxt('datafiles/HEOM_7LS_lambda_35_T_77_tau_50.txt')
f4 = np.loadtxt('datafiles/OMT_7LS_lambda_35_T_77_tau_50.txt')
f5 = np.loadtxt('datafiles/SQC_7LS_lambda_35_T_77_tau_50.txt')

plt.figure(figsize=(24,5))
plt.subplots_adjust(wspace=0.2)

plt.subplot(1,5,1)
for i in range(7):
    # plt.plot(f1[:,0], f1[:,i+1], label='%d'%(i+1), lw=2)
    plt.plot(f1[:,0], f1[:,i+1], color=colors[i], label='%d'%(i+1))
plt.text(0.7, 0.7, r'wOMT', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,15])
plt.xlabel(r'$\omega_ct$', fontsize=18)
plt.legend(frameon=False, ncols=2, loc=(0.05,0.6))
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))

plt.subplot(1,5,2)
for i in range(7):
    plt.plot(f3[:,0], f3[:,i+1], color=colors[i], lw=2)
plt.text(0.7, 0.7, 'HEOM', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,15])
plt.xlabel(r'$\omega_ct$', fontsize=18)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))

plt.subplot(1,5,3)
for i in range(7):
    plt.plot(f2[:,0], f2[:,i+1], color=colors[i])
plt.text(0.7, 0.7, r'MASH', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,15])
plt.xlabel(r'$\omega_ct$', fontsize=18)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))

plt.subplot(1,5,4)
for i in range(7):
    plt.plot(f4[:,0], f4[:,i+1], color=colors[i])
plt.text(0.7, 0.7, r'OMT', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,15])
plt.xlabel(r'$\omega_ct$', fontsize=18)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))

plt.subplot(1,5,5)
for i in range(7):
    plt.plot(f5[:,0], f5[:,i+1], color=colors[i])
plt.text(0.7, 0.7, r'SQC', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,15])
plt.xlabel(r'$\omega_ct$', fontsize=18)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))

# plt.savefig(pic_dir + '7LS_population_lowT.pdf', bbox_inches='tight', dpi=800)

plt.show()

# %%
f1 = np.loadtxt('datafiles/HEOM_7LS_lambda_35_T_77_tau_50.txt')
f2 = np.loadtxt('datafiles/full_g_wOMT_7LS_lambda_35_T_77_tau_50.txt')
f3 = np.loadtxt('datafiles/g_0.3_wOMT_7LS_lambda_35_T_77_tau_50.txt')
f4 = np.loadtxt('datafiles/g_0.25_wOMT_7LS_lambda_35_T_77_tau_50.txt')

plt.figure(figsize=(7*golden_ratio,10))
plt.subplots_adjust(wspace=0.15)

plt.subplot(2,2,1)
for i in range(7):
    plt.plot(f1[:,0], f1[:,i+1], label='%d'%(i+1), color=colors[i])
plt.text(0.7, 0.7, r'HEOM', transform=plt.gca().transAxes, fontsize=18)
plt.xlim([0,20])
plt.legend(frameon=False, ncols=3)
plt.xlabel(r'$\omega_ct$', fontsize=18)
plt.tick_params(left=True, right=True)

plt.subplot(2,2,2)
for i in range(7):
    plt.plot(f2[:,0], f2[:,i+1], color=colors[i])
plt.text(0.7, 0.7, r'wOMT' +'\n' + r'$\gamma = (\sqrt{3}-1)/2$', transform=plt.gca().transAxes, fontsize=18, horizontalalignment='center')
plt.xlim([0,20])
plt.xlabel(r'$\omega_ct$', fontsize=18)
plt.tick_params(left=True, right=True)

plt.subplot(2,2,3)
for i in range(7):
    plt.plot(f3[:,0], f3[:,i+1], color=colors[i])
plt.text(0.7, 0.7, r'wOMT' +'\n' + r'$\gamma = 3/10$', transform=plt.gca().transAxes, fontsize=18, horizontalalignment='center')
plt.xlim([0,20])
plt.xlabel(r'$\omega_ct$', fontsize=18)
plt.tick_params(left=True, right=True)

plt.subplot(2,2,4)
for i in range(7):
    plt.plot(f4[:,0], f4[:,i+1], color=colors[i])
plt.text(0.7, 0.7, r'wOMT' +'\n' + r'$\gamma = 1/4$', transform=plt.gca().transAxes, fontsize=18, horizontalalignment='center')
plt.xlim([0,20])
plt.xlabel(r'$\omega_ct$', fontsize=18)

# plt.savefig('7LS_gamma_lowT.pdf', bbox_inches='tight', dpi=800)

plt.show()
